# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
df = pd.read_excel("avalanche_discrete3.xlsx")
df=df.drop("inventory", axis=1)
df.head()
# Out:
#    Elevation  Slope  Aspect  Plan Curvature  Profile Curvature  \
# 0          3      5       5               4                  2
# 1          1      3       6               4                  2
# 2          2      2       7               4                  2
# 3          1      1       5               4                  2
# 4          2      3       0               4                  3
#
#    Topographic Wetness Index  Terrain Roughness Index  \
# 0                          2                        4
# 1                          2                        4
# 2                          2                        4
# 3                          2                        3
# 4                          3                        4
#
#    Topographic Position Index  Proximity to Road  Proximity to Stream  \
# 0                           4                  2                    1
# 1                           4                  1                    1
# ...

# %%
df_columns=df.columns

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                   VIF  Tolerance
# Elevation                   15.207939   0.065755
# Slope                        1.532353   0.652591
# Aspect                       1.024908   0.975697
# Plan Curvature               1.217036   0.821669
# Profile Curvature            1.241620   0.805399
# Topographic Wetness Index    1.286045   0.777578
# Terrain Roughness Index      1.123004   0.890469
# Topographic Position Index   1.261615   0.792635
# Proximity to Road            1.346450   0.742694
# Proximity to Stream          1.084108   0.922418
# Average Wind Speed           8.283330   0.120724
# Average Min Temperature     13.616525   0.073440
# Average Max Temperature     18.919568   0.052855
# Average Solar Radiation      4.901631   0.204014
# Annual Precipitation         1.394970   0.716861
# Annual Mean Temperature     18.791301   0.053216
# Lithology                    1.138662   0.878223
# Land Use                     1.371819   0.728959

# %%
df=df.drop("Average Max Temperature", axis=1)
df_columns=df.columns

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                   VIF  Tolerance
# Elevation                   14.492174   0.069003
# Slope                        1.529500   0.653808
# Aspect                       1.024794   0.975806
# Plan Curvature               1.216888   0.821768
# Profile Curvature            1.241587   0.805421
# Topographic Wetness Index    1.285525   0.777892
# Terrain Roughness Index      1.122990   0.890480
# Topographic Position Index   1.260270   0.793481
# Proximity to Road            1.343768   0.744176
# Proximity to Stream          1.078924   0.926849
# Average Wind Speed           6.388107   0.156541
# Average Min Temperature     13.247710   0.075485
# Average Solar Radiation      4.874563   0.205147
# Annual Precipitation         1.393131   0.717807
# Annual Mean Temperature     16.901152   0.059168
# Lithology                    1.138459   0.878381
# Land Use                     1.369334   0.730282

# %%
df=df.drop("Average Min Temperature", axis=1)
df_columns=df.columns

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                   VIF  Tolerance
# Elevation                   13.378674   0.074746
# Slope                        1.514281   0.660379
# Aspect                       1.024777   0.975822
# Plan Curvature               1.216884   0.821771
# Profile Curvature            1.241313   0.805599
# Topographic Wetness Index    1.285522   0.777894
# Terrain Roughness Index      1.122859   0.890584
# Topographic Position Index   1.260258   0.793488
# Proximity to Road            1.341163   0.745622
# Proximity to Stream          1.070671   0.933994
# Average Wind Speed           6.234157   0.160407
# Average Solar Radiation      4.773944   0.209470
# Annual Precipitation         1.290459   0.774918
# Annual Mean Temperature     13.829093   0.072311
# Lithology                    1.136188   0.880136
# Land Use                     1.367737   0.731135

# %%
df=df.drop("Average Wind Speed", axis=1)
df_columns=df.columns

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                   VIF  Tolerance
# Elevation                   12.827463   0.077958
# Slope                        1.494480   0.669129
# Aspect                       1.024728   0.975868
# Plan Curvature               1.216776   0.821844
# Profile Curvature            1.236738   0.808578
# Topographic Wetness Index    1.285470   0.777926
# Terrain Roughness Index      1.120974   0.892081
# Topographic Position Index   1.259327   0.794075
# Proximity to Road            1.311855   0.762279
# Proximity to Stream          1.040416   0.961154
# Average Solar Radiation      4.737370   0.211088
# Annual Precipitation         1.149807   0.869712
# Annual Mean Temperature     12.153932   0.082278
# Lithology                    1.115112   0.896771
# Land Use                     1.316848   0.759389

# %%
df=df.drop("Annual Mean Temperature", axis=1)
df_columns=df.columns

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                  VIF  Tolerance
# Elevation                   4.879395   0.204943
# Slope                       1.484347   0.673697
# Aspect                      1.024283   0.976293
# Plan Curvature              1.216363   0.822123
# Profile Curvature           1.235934   0.809105
# Topographic Wetness Index   1.285467   0.777927
# Terrain Roughness Index     1.119006   0.893650
# Topographic Position Index  1.259112   0.794211
# Proximity to Road           1.310846   0.762866
# Proximity to Stream         1.035085   0.966104
# Average Solar Radiation     4.449877   0.224725
# Annual Precipitation        1.132482   0.883016
# Lithology                   1.113035   0.898445
# Land Use                    1.307938   0.764562

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='vlag', fmt=".2f")
fig.savefig('pearson.jpg', dpi=150,bbox_inches='tight')
# Out:
# <ipython-input-15-bb0d2b6c8bc5>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
df=df.drop("Average Solar Radiation", axis=1)
df_columns=df.columns

# %%
def calculate_vif(df, features):    
    vif, tolerance = {}, {}
    for feature in features:
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        r2 = LinearRegression().fit(X, y).score(X, y)                
        tolerance[feature] = 1 - r2
        vif[feature] = 1/(tolerance[feature])
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})
calculate_vif(df=df, features=df_columns)
# Out:
#                                  VIF  Tolerance
# Elevation                   1.773516   0.563852
# Slope                       1.454843   0.687360
# Aspect                      1.024135   0.976433
# Plan Curvature              1.216080   0.822314
# Profile Curvature           1.232615   0.811284
# Topographic Wetness Index   1.277224   0.782948
# Terrain Roughness Index     1.118866   0.893762
# Topographic Position Index  1.257225   0.795403
# Proximity to Road           1.307072   0.765069
# Proximity to Stream         1.035004   0.966180
# Annual Precipitation        1.113638   0.897958
# Lithology                   1.111471   0.899708
# Land Use                    1.304074   0.766828

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='vlag', fmt=".2f")
fig.savefig('pearson.jpg', dpi=400,bbox_inches='tight')
# Out:
# <ipython-input-18-ba4115ad54da>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
df = pd.read_excel("avalanche_discrete3.xlsx")
df=df.drop("Average Max Temperature", axis=1)
df=df.drop("Average Min Temperature", axis=1)
df=df.drop("Average Wind Speed", axis=1)
df=df.drop("Annual Mean Temperature", axis=1)
df=df.drop("Average Solar Radiation", axis=1)

# %%
file_name = 'avalanche_discrete_selected3.xlsx'
df.to_excel(file_name, index=False)

# %% [markdown]
# ### Information Gain

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:.1f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:.3f}'.format(p.get_width())
                import random
                ext = random.uniform(0, 0.015)
                import decimal
                decimal.getcontext().rounding = decimal.ROUND_CEILING
                ax.text(_x, _y, str(value) + " ± " + str(float(round(decimal.Decimal(ext), ndigits=3))) , ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
fi_df = pd.DataFrame({
    "feature_importances" : [0.556,0.331,0.297,0.254,0.230,0.208,0.199,0.127,0.112,0.085,0.079,0.043,0.040],
    "features" : ['Elevation', 'Land Use', "Slope", "Annual Precipitation", "Proximity to Road", "Topographic Wetness Index","Lithology","Aspect","Terrain Roughness Index","Plan Curvature","Proximity to Stream","Topographic Position Index","Profile Curvature"]
})

fi_df.sort_values(by="feature_importances", ascending=False, inplace=True)
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.set_context('paper', font_scale = 3)
ax = sns.barplot(x="feature_importances", y="features", palette="cividis", data=fi_df, ci=None)
show_values(ax, "h", space=0.005)
plt.xlabel("Average Merit",labelpad=15, size=36)
plt.ylabel("Conditioning Factors",labelpad=15, size=36)
plt.xlim(0.0, 0.65)
fig = plt.gcf()
fig.set_size_inches((28, 19), forward=False)
fig.savefig("IG_method.jpg", dpi=150)

plt.show()
